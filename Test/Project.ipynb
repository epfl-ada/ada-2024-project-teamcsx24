# %%
import numpy as np
import pandas as pd
import tarfile
import matplotlib.pyplot as plt
import missingno as msno

# %% [markdown]
# ## Movie Metadata

# %%
df_movie_metadata = pd.read_csv('../../ada-2024-project-teamcsx24/data/MovieSummaries/movie.metadata.tsv', sep='\t', encoding='utf-8', na_values=['NA'], header=None)
df_movie_metadata.columns = ['id','freebase_id','Title','release_date','revenue','runtime','language','country','genre']
df_movie_metadata.head(10)
# Out:
#          id freebase_id                                              Title  \
# 0    975900   /m/03vyhn                                     Ghosts of Mars
# 1   3196793   /m/08yl5d  Getting Away with Murder: The JonBenét Ramsey ...
# 2  28463795  /m/0crgdbh                                        Brun bitter
# 3   9363483  /m/0285_cd                                   White Of The Eye
# 4    261236   /m/01mrr1                                  A Woman in Flames
# 5  13696889  /m/03cfc81                                      The Gangsters
# 6  18998739  /m/04jcqvw                          The Sorcerer's Apprentice
# 7  10408933  /m/02qc0j7                           Alexander's Ragtime Band
# 8   9997961  /m/06_y2j7                                     Contigo y aquí
# 9   2345652   /m/075f66                                   City of the Dead
#
#   release_date     revenue  runtime  \
# 0   2001-08-24  14010832.0     98.0
# 1   2000-02-16         NaN     95.0
# ...

# %%
df_movie_metadata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81741 entries, 0 to 81740
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            81741 non-null  int64
#  1   freebase_id   81741 non-null  object
#  2   Title         81741 non-null  object
#  3   release_date  74839 non-null  object
#  4   revenue       8401 non-null   float64
#  5   runtime       61291 non-null  float64
#  6   language      81741 non-null  object
#  7   country       81741 non-null  object
#  8   genre         81741 non-null  object
# dtypes: float64(2), int64(1), object(6)
# memory usage: 5.6+ MB

# %%
df_movie_metadata.isnull().sum()
# Out:
# id                  0
# freebase_id         0
# Title               0
# release_date     6902
# revenue         73340
# runtime         20450
# language            0
# country             0
# genre               0
# dtype: int64

# %%
df_movie_metadata['release_date'] = df_movie_metadata['release_date'].replace('1010-12-02', '2010-12-02')

# %%
df_movie_metadata['release_date'].iloc[62836] = df_movie_metadata['release_date'].iloc[62836].replace('1010-12-02', '2010-12-02')
# Out:
# C:\Users\aurel\AppData\Local\Temp\ipykernel_21056\3931569424.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# ...

# %%
df_movie_metadata.iloc[62836]
# Out:
# id                                                       29666067
# freebase_id                                            /m/0fphzrf
# Title                                              Hunting Season
# release_date                                           2010-12-02
# revenue                                                12160978.0
# runtime                                                     140.0
# language        {"/m/02hwyss": "Turkish Language", "/m/02h40lc...
# country                                   {"/m/01znc_": "Turkey"}
# genre           {"/m/0lsxr": "Crime Fiction", "/m/02n4kr": "My...
# Name: 62836, dtype: object

# %%
df_movie_metadata['release_date'] = pd.to_datetime(df_movie_metadata['release_date'], format='mixed')
df_movie_metadata['release_date'] = df_movie_metadata['release_date'].dt.year
df_movie_metadata.head(10)
# Out:
#          id freebase_id                                              Title  \
# 0    975900   /m/03vyhn                                     Ghosts of Mars
# 1   3196793   /m/08yl5d  Getting Away with Murder: The JonBenét Ramsey ...
# 2  28463795  /m/0crgdbh                                        Brun bitter
# 3   9363483  /m/0285_cd                                   White Of The Eye
# 4    261236   /m/01mrr1                                  A Woman in Flames
# 5  13696889  /m/03cfc81                                      The Gangsters
# 6  18998739  /m/04jcqvw                          The Sorcerer's Apprentice
# 7  10408933  /m/02qc0j7                           Alexander's Ragtime Band
# 8   9997961  /m/06_y2j7                                     Contigo y aquí
# 9   2345652   /m/075f66                                   City of the Dead
#
#    release_date     revenue  runtime  \
# 0        2001.0  14010832.0     98.0
# 1        2000.0         NaN     95.0
# ...

# %%
df_movie_metadata['release_date'].value_counts().sort_index().plot(kind='bar', figsize=(20,10))
# Out:
# <Axes: xlabel='release_date'>

# %%
df_movie_metadata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81741 entries, 0 to 81740
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            81741 non-null  int64
#  1   freebase_id   81741 non-null  object
#  2   Title         81741 non-null  object
#  3   release_date  74839 non-null  float64
#  4   revenue       8401 non-null   float64
#  5   runtime       61291 non-null  float64
#  6   language      81741 non-null  object
#  7   country       81741 non-null  object
#  8   genre         81741 non-null  object
# dtypes: float64(3), int64(1), object(5)
# memory usage: 5.6+ MB

# %%
msno.matrix(df_movie_metadata)
plt.figure(figsize = (13,10))
plt.show()

# %%
import missingno
import matplotlib

print("missingno version:", missingno.__version__)
print("matplotlib version:", matplotlib.__version__)
# Out:
# missingno version: 0.4.2
# matplotlib version: 3.9.2

# %% [markdown]
# ## Character Metadata

# %%
df_character_metadata = pd.read_csv('C:/Users/aurel/ADA2024/Aurel/MovieSummaries/character.metadata.tsv', sep='\t', encoding='utf-8', na_values=['NA'], header=None)
df_character_metadata.columns = ['Movie_id','freebase_movie_id','Movie_release_date','Character_name','Actor_birth','Actor_gender','Actor_height','freebase_ctor_ethnicity_id','Actor_name', 'Actor_age_movie_released','Freebase character/actor map ID','Freebase character ID', 'Freebase actor ID' ]
df_character_metadata.head(10)
# Out:
#    Movie_id freebase_movie_id Movie_release_date              Character_name  \
# 0    975900         /m/03vyhn         2001-08-24                    Akooshay
# 1    975900         /m/03vyhn         2001-08-24  Lieutenant Melanie Ballard
# 2    975900         /m/03vyhn         2001-08-24         Desolation Williams
# 3    975900         /m/03vyhn         2001-08-24          Sgt Jericho Butler
# 4    975900         /m/03vyhn         2001-08-24             Bashira Kincaid
# 5    975900         /m/03vyhn         2001-08-24   Commander Helena Braddock
# 6    975900         /m/03vyhn         2001-08-24                    Whitlock
# 7    975900         /m/03vyhn         2001-08-24              Big Daddy Mars
# 8    975900         /m/03vyhn         2001-08-24            Michael Descanso
# 9    975900         /m/03vyhn         2001-08-24                         Uno
#
#   Actor_birth Actor_gender  Actor_height freebase_ctor_ethnicity_id  \
# ...

# %%
df_character_metadata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 450669 entries, 0 to 450668
# Data columns (total 13 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   Movie_id                         450669 non-null  int64
#  1   freebase_movie_id                450669 non-null  object
#  2   Movie_release_date               440674 non-null  object
#  3   Character_name                   192794 non-null  object
#  4   Actor_birth                      344524 non-null  object
#  5   Actor_gender                     405060 non-null  object
#  6   Actor_height                     154824 non-null  float64
#  7   freebase_ctor_ethnicity_id       106058 non-null  object
#  8   Actor_name                       449441 non-null  object
#  9   Actor_age_movie_released         292556 non-null  float64
#  10  Freebase character/actor map ID  450669 non-null  object
# ...

# %%
df_character_metadata.isnull().sum()
# Out:
# Movie_id                                0
# freebase_movie_id                       0
# Movie_release_date                   9995
# Character_name                     257875
# Actor_birth                        106145
# Actor_gender                        45609
# Actor_height                       295845
# freebase_ctor_ethnicity_id         344611
# Actor_name                           1228
# Actor_age_movie_released           158113
# Freebase character/actor map ID         0
# Freebase character ID              257865
# Freebase actor ID                     815
# dtype: int64

# %% [markdown]
# ## Title Basics from IMDb

# %%
df_title_additional = pd.read_csv('../../data/additionalData/IMDb_title.basics.tsv.gz', sep='\t')
df_title_additional = df_title_additional.rename(columns={'tconst': 'imdb_id'})
df_title_additional = df_title_additional.rename(columns={'originalTitle': 'original_title'})
df_title_additional.head(2)

# %%
df_title_additional.info()

# %% [markdown]
# ## Title Ratings from IMDb

# %%
df_rating_additional = pd.read_csv('../../data/additionalData/IMDb_title.ratings.tsv.gz', sep='\t')
df_rating_additional = df_rating_additional.rename(columns={'tconst': 'imdb_id'})
df_rating_additional.head(2)

# %%
df_rating_additional.info()
